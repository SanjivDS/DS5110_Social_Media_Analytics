# %% [markdown]
# # DS5110 IDMP Final Project

# %% [markdown]
# Team Members
#
# *   Sanjiv Motilal Choudhari
# *   Shivram Nekkanti

# %% [markdown]
# # Objective

# %% [markdown]
# In the dynamic world of motorsport, fan engagement and sentiment analysis play a vital role in understanding audience perception and preferences. This project explores the wealth of insights hidden within fan comments on online platforms, focusing on the 2024 Formula One season's first 20 races. By analyzing 100,000 scraped comments, this project aims to uncover trends, sentiments, and public opinions related to drivers, teams, and the races themselves.
#
# The objective is to apply Natural Language Processing (NLP) techniques to extract meaningful information from the comments. This includes identifying mentions of racers and racing teams, classifying emotions such as joy, anger, sadness, surprise, and fear, and understanding how fans perceive individual drivers and teams over time.

# %% [markdown]
# # Section 1 : Data Loading and Preprocessing

# %% [markdown]
# This section covers loading the data from the zip file, extracting relevant comments based on keywords, and preparing the data for further analysis.

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# !unzip Data.zip
# Out:
# Archive:  Data.zip
#   inflating: British.csv
#   inflating: Canada.csv
#   inflating: Chinese.csv
#   inflating: Emilia_Romagna.csv
#   inflating: Finale.csv
#   inflating: Hungarian.csv
#   inflating: Italian.csv
#   inflating: Japanese.csv
#   inflating: Miami.csv
#   inflating: Monaco.csv
#   inflating: Qatar.csv
#   inflating: Saudi.csv
#   inflating: australian.csv
#   inflating: Azerbaijan.csv
#   inflating: Baharain.csv
#   inflating: Belgian.csv

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
import pandas as pd
import zipfile

# Path to the zip file
zip_file_path = '/content/Data.zip'

# Creating a ZipFile object
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Getting a list of all CSV files within the archive
    csv_files = [file for file in zip_ref.namelist() if file.endswith('.csv')]

    dataframes = []
    # Iterating through each CSV file
    for csv_file in csv_files:
        # Reading the CSV files directly from the zip archive
        with zip_ref.open(csv_file, 'r') as file:
            df = pd.read_csv(file)
            dataframes.append(df)

# Concatenate all dataframes
df = pd.concat(dataframes, ignore_index=True)
print(df)
# Out:
#                             author          published_at  \
# 0            @michaelcortright5525  2024-12-08T16:02:35Z
# 1                         @oreskec  2024-12-08T11:50:44Z
# 2                       @Bilnation  2024-12-07T22:39:57Z
# 3                   @anthonymg8870  2024-12-07T10:23:59Z
# 4      @mykatiesdouglaskatie-kp1jg  2024-12-06T05:34:57Z
# ...                            ...                   ...
# 61922                  @AhmadRiyal  2024-07-28T15:49:24Z
# 61923              @DayTimeRunners  2024-07-28T15:49:21Z
# 61924                     @Topsu11  2024-07-28T15:49:20Z
# 61925          @eliashargaming6143  2024-07-28T15:49:19Z
# 61926                 @sameern9018  2024-07-28T15:49:15Z
#
#                  updated_at  like_count  \
# 0      2024-12-08T16:02:35Z         0.0
# 1      2024-12-08T11:50:44Z         0.0
# 2      2024-12-07T22:39:57Z         2.0
# 3      2024-12-07T10:23:59Z         0.0
# 4      2024-12-06T05:34:57Z         0.0
# ...                     ...         ...
# 61922  2024-07-28T15:49:24Z         0.0
# 61923  2024-07-28T15:49:21Z         0.0
# 61924  2024-07-28T15:49:20Z         1.0
# 61925  2024-07-28T16:56:34Z      2434.0
# 61926  2024-07-28T15:49:15Z        13.0
#
#                                                     text
# 0      I cried when it happened and I cried again wat...
# 1      <a href="https://www.youtube.com/watch?v=yPvoK...
# 2      This was the best Silverstone race of all time...
# 3      I remember watching this race. It was mouthwat...
# 4                                           Missing this
# ...                                                  ...
# 61922                                              First
# 61923                                            Amazing
# 61924                                              First
# 61925  That was the drive of the year from George Rus...
# 61926                                       First view 🥇
#
# [61927 rows x 5 columns]

# %% [markdown]
# #  Section 2: Keyword-based Comment Filtering

# %% [markdown]
# Here, we identify and extract comments that mention specific drivers or teams using a predefined list of keywords.

# %%
df.shape
# Out:
# (61927, 5)

# %%
# Defining keywords for filtering comments
keywords = ["Max", "Verstappen", "Lando", "Norris", "Charles", "Leclerc", "Carlos", "Sainz", "Oscar", "Piastri","Fernando", "Alonso"] #"Red Bull", "McLaren", "Ferrari", "race", "lap", "overtake", "collision", "Penalty", "FIA"
# Filtering comments containing any keywords
df['relevant'] = df['text'].astype(str).apply(lambda x: any(word.lower() in x.lower() for word in keywords))
relevant_comments = df[df['relevant']]

print(relevant_comments.head())
# Out:
#                    author          published_at            updated_at  \
# 18         @Heizen_Cookzz  2024-11-08T12:49:28Z  2024-11-08T12:49:28Z
# 27  @eletricidadeVeicular  2024-10-18T23:40:00Z  2024-10-18T23:40:00Z
# 32          @srthebox4946  2024-10-13T01:18:24Z  2024-10-13T01:18:24Z
# 35       @DonaldClark-p1h  2024-10-10T19:40:59Z  2024-10-10T19:40:59Z
# 38   @southerncomfort1339  2024-10-06T01:37:08Z  2024-10-06T01:37:08Z
#
#     like_count                                               text  relevant
# 18         0.0                                Verstappen the GOAT      True
# 27         0.0             Nando vai chegar na cola do Verstappen      True
# 32         0.0      Max locked in for like only the last few laps      True
# 35         0.0  Jones Elizabeth Rodriguez Charles Williams Jen...      True
# 38         0.0  With 3 laps remaining why did LANDO just jump ...      True

# %% [markdown]
# #  Section 3: Top Comments

# %% [markdown]
# This section analyzes the most liked comments to understand the key topics and themes discussed by users.

# %%
# Sorting relevant comments by 'like_count' in descending order and pick the top 10
top_comments = relevant_comments.nlargest(10, 'like_count')[['author', 'text', 'like_count']]
print("Top 10 Most Liked Comments:\n", top_comments)
# Out:
# Top 10 Most Liked Comments:
#                     author                                               text  \
# 47831    @AMX_1790.POTATO  Fun fact: in the last 2 non verstappen wins, C...
# 47929      @versiable8041  Sainz losing his Appendix is the best thing to...
# 23096        @TheMutanBoy  CHARLES SACRIFICED THE WHOLE SEASON FOR 2 HOME...
# 23004     @Mufasa_Youtube  &quot;Lando Norris finally got the start he ne...
# 13033       @eluminaughty  Norris closing a 6 second gap to an RB driven ...
# 61497      @kevinbray9550  Piastri is a revelation. He overtakes like a c...
# 23043  @ChartheSkywing352  Leclerc won Monaco and Monza, the biggest race...
# 47434   @glandelfield3273  Ferrari replacing Sainz with Hamilton is just ...
# 13023    @kovelamanas9905  Lando: I don&#39;t have pace, gets chased by L...
# 51336           @iiSpicyy  What a picturesque moment with Piastri and LeC...
#
#        like_count
# 47831     49256.0
# 47929     20196.0
# 23096     19529.0
# 23004     18159.0
# 13033     16003.0
# 61497     15757.0
# 23043     13022.0
# 47434     12979.0
# 13023     12935.0
# 51336     12181.0

# %% [markdown]
# # Section 4: Emotion Analysis with Hugging Face

# %%
# !pip install nrclex
# Out:
# Collecting nrclex
#   Downloading NRCLex-4.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (from nrclex) (0.17.1)
# INFO: pip is looking at multiple versions of nrclex to determine which version is compatible with other requirements. This could take a while.
#   Downloading NRCLex-3.0.0.tar.gz (396 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.4/396.4 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob->nrclex) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob->nrclex) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob->nrclex) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob->nrclex) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob->nrclex) (4.66.6)
# Building wheels for collected packages: nrclex
#   Building wheel for nrclex (setup.py) ... done
#   Created wheel for nrclex: filename=NRCLex-3.0.0-py3-none-any.whl size=43308 sha256=e411c3f9490064235198ffa2c097b4fd27d0451ed664da8b1a0075318ea83fa1
#   Stored in directory: /root/.cache/pip/wheels/d2/10/44/6abfb1234298806a145fd6bcaec8cbc712e88dd1cd6cb242fa
# Successfully built nrclex
# Installing collected packages: nrclex
# Successfully installed nrclex-3.0.0

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
nltk.download('wordnet')
nltk.download('movie_reviews')
nltk.download('conll2000')
nltk.download('twitter_samples')

from textblob import TextBlob
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.

# %% [markdown]
# This section performs in-depth emotion analysis on the comments using Hugging Face's emotion classification pipeline

# %%
# !pip install 'spacy[transformers]'
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy[transformers] in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (0.15.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (2.10.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy[transformers]) (1.26.4)
# Collecting spacy-transformers<1.4.0,>=1.1.2 (from spacy[transformers])
#   Downloading spacy_transformers-1.3.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy[transformers]) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[transformers]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[transformers]) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[transformers]) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (2024.8.30)
# Collecting transformers<4.37.0,>=3.4.0 (from spacy-transformers<1.4.0,>=1.1.2->spacy[transformers])
#   Downloading transformers-4.36.2-py3-none-any.whl.metadata (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers<1.4.0,>=1.1.2->spacy[transformers]) (2.5.1+cu121)
# Collecting spacy-alignments<1.0.0,>=0.7.2 (from spacy-transformers<1.4.0,>=1.1.2->spacy[transformers])
#   Downloading spacy_alignments-0.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy[transformers]) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy[transformers]) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy[transformers]) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy[transformers]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy[transformers]) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy[transformers]) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy[transformers]) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy[transformers]) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy[transformers]) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy[transformers]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy[transformers]) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy[transformers]) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.1.2->spacy[transformers]) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.1.2->spacy[transformers]) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.1.2->spacy[transformers]) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.1.2->spacy[transformers]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->spacy-transformers<1.4.0,>=1.1.2->spacy[transformers]) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers<1.4.0,>=1.1.2->spacy[transformers]) (0.26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers<1.4.0,>=1.1.2->spacy[transformers]) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers<1.4.0,>=1.1.2->spacy[transformers]) (2024.9.11)
# Collecting tokenizers<0.19,>=0.14 (from transformers<4.37.0,>=3.4.0->spacy-transformers<1.4.0,>=1.1.2->spacy[transformers])
#   Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers<1.4.0,>=1.1.2->spacy[transformers]) (0.4.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy[transformers]) (0.1.2)
# Downloading spacy_transformers-1.3.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (197 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.8/197.8 kB 13.2 MB/s eta 0:00:00
# Downloading spacy_alignments-0.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.0/314.0 kB 19.4 MB/s eta 0:00:00
# Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 16.8 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 28.2 MB/s eta 0:00:00
# Installing collected packages: spacy-alignments, tokenizers, transformers, spacy-transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.3
#     Uninstalling transformers-4.46.3:
#       Successfully uninstalled transformers-4.46.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.36.2 which is incompatible.
# Successfully installed spacy-alignments-0.9.1 spacy-transformers-1.3.5 tokenizers-0.15.2 transformers-4.36.2
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.15.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import re
from transformers import pipeline

# Loading Hugging Face's emotion-classification pipeline
emotion_analyzer = pipeline("text-classification", model="joeddav/distilbert-base-uncased-go-emotions-student", return_all_scores=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.75k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:519: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location=map_location)
# tokenizer_config.json:   0%|          | 0.00/421 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
selected_emotions = {"surprise", "sadness", "joy", "disappointment", "anger"}

drivers = {
    "Max Verstappen": ["Max", "Verstappen"],
    "Lewis Hamilton": ["Lewis", "Hamilton"],
    "Lando Norris": ["Lando", "Norris"],
    "Sergio Perez": ["Sergio", "Perez"],
    "Carlos Sainz": ["Carlos", "Sainz"],
    "Daniel Ricciardo": ["Daniel", "Ricciardo"],
    "Valtteri Bottas": ["Valtteri", "Bottas"],
    "Fernando Alonso": ["Fernando", "Alonso"],
    "Oscar Piastri": ["Oscar", "Piastri"],
    "Esteban Ocon": ["Esteban", "Ocon"],
    "Charles Leclerc":["Charles", "Leclerc"]
}

all_driver_variations = [name for variations in drivers.values() for name in variations]

# Extracting drivers from the text using pattern matching
def extract_drivers(text, drivers, all_driver_variations):
    pattern = r'\b(' + '|'.join(re.escape(name) for name in all_driver_variations) + r')\b'
    detected_names = re.findall(pattern, text, flags=re.IGNORECASE)

    detected_drivers = set()  # Avoid duplicates
    for full_name, variations in drivers.items():
        if any(detected_name.lower() in [v.lower() for v in variations] for detected_name in detected_names):
            detected_drivers.add(full_name)

    return list(detected_drivers)

# Splitting the comment into clauses related to each driver
def split_by_driver(comment, driver, drivers, all_driver_variations):
    driver_variations = drivers[driver]
    driver_pattern = re.compile(r'(\b' + '|'.join(re.escape(name) for name in driver_variations) + r'\b.*?(\.|$))', flags=re.IGNORECASE)

    driver_related_clauses = driver_pattern.findall(comment)

    return [clause[0] for clause in driver_related_clauses]  # Return only the matched clauses

# Analyzing emotions for each driver-related clause
def analyze_emotions(comment, drivers, all_driver_variations):
    detected_drivers = extract_drivers(comment, drivers, all_driver_variations)

    if not detected_drivers:
        return "No drivers detected"

    driver_emotions = {}

    for driver in detected_drivers:
        clauses = split_by_driver(comment, driver, drivers, all_driver_variations)

        if clauses:
            # Performing emotion analysis on each clause related to the specific driver
            for clause in clauses:
                emotion_results = emotion_analyzer(clause)[0]  # Get the emotion scores

                # Filtering only the emotions we're interested in
                filtered_emotions = [emotion for emotion in emotion_results if emotion['label'] in selected_emotions]

                # Sorting by the highest score and taking the top filtered emotion
                top_emotion = max(filtered_emotions, key=lambda x: x['score'], default=None)

                if top_emotion:
                    emotion_label = top_emotion['label']

                    # If driver already has an emotion, keep the strongest one
                    if driver in driver_emotions:
                        # Update if the new emotion score is higher
                        if top_emotion['score'] > driver_emotions[driver]['score']:
                            driver_emotions[driver] = {'emotion': emotion_label, 'score': top_emotion['score']}
                    else:
                        driver_emotions[driver] = {'emotion': emotion_label, 'score': top_emotion['score']}

    # Return only the filtered emotions for each driver
    return {driver: data['emotion'] for driver, data in driver_emotions.items()}

# %%
df = relevant_comments.copy()

# %%
df.head(10)
# Out:
#                    author          published_at            updated_at  \
# 18         @Heizen_Cookzz  2024-11-08T12:49:28Z  2024-11-08T12:49:28Z
# 27  @eletricidadeVeicular  2024-10-18T23:40:00Z  2024-10-18T23:40:00Z
# 32          @srthebox4946  2024-10-13T01:18:24Z  2024-10-13T01:18:24Z
# 35       @DonaldClark-p1h  2024-10-10T19:40:59Z  2024-10-10T19:40:59Z
# 38   @southerncomfort1339  2024-10-06T01:37:08Z  2024-10-06T01:37:08Z
# 45    @rafaelhenrique6649  2024-09-28T11:28:06Z  2024-09-28T11:28:06Z
# 51          @JDMLegends99  2024-09-20T08:55:56Z  2024-09-20T08:55:56Z
# 52               @ddb2029  2024-09-19T18:27:53Z  2024-09-19T18:27:53Z
# 59         @vale_tantus25  2024-09-12T16:11:26Z  2024-09-12T16:11:26Z
# 64       @PowerPuffJewels  2024-09-07T01:19:44Z  2024-09-07T01:19:44Z
#
#     like_count                                               text  relevant
# 18         0.0                                Verstappen the GOAT      True
# 27         0.0             Nando vai chegar na cola do Verstappen      True
# 32         0.0      Max locked in for like only the last few laps      True
# 35         0.0  Jones Elizabeth Rodriguez Charles Williams Jen...      True
# 38         0.0  With 3 laps remaining why did LANDO just jump ...      True
# 45         0.0   Denovo esse mano falando q foguete não dá ré🤦🏾🤣😂      True
# 51         0.0  McLaren Dominating on this one Norris is in a ...      True
# 52         0.0  Lewis and Max absolutely nailed it with the se...      True
# 59         0.0  <a href="https://www.youtube.com/watch?v=yPvoK...      True
# 64         0.0  Can’t wait to see him win races in red along s...      True

# %%
def apply_emotion_analysis_to_comments(df, drivers, all_driver_variations):
    # Apply the analyze_emotions function to each comment in the 'text' column
    df['driver_sentiments'] = df['text'].apply(lambda comment: analyze_emotions(comment, drivers, all_driver_variations))
    return df

# Now applying the emotion analysis function to the dataframe
df_with_emotions = apply_emotion_analysis_to_comments(df, drivers, all_driver_variations)

# %%
# Displaying the dataframe with the sentiment analysis result
df_with_emotions.head(10)
# Out:
#                    author          published_at            updated_at  \
# 18         @Heizen_Cookzz  2024-11-08T12:49:28Z  2024-11-08T12:49:28Z
# 27  @eletricidadeVeicular  2024-10-18T23:40:00Z  2024-10-18T23:40:00Z
# 32          @srthebox4946  2024-10-13T01:18:24Z  2024-10-13T01:18:24Z
# 35       @DonaldClark-p1h  2024-10-10T19:40:59Z  2024-10-10T19:40:59Z
# 38   @southerncomfort1339  2024-10-06T01:37:08Z  2024-10-06T01:37:08Z
# 45    @rafaelhenrique6649  2024-09-28T11:28:06Z  2024-09-28T11:28:06Z
# 51          @JDMLegends99  2024-09-20T08:55:56Z  2024-09-20T08:55:56Z
# 52               @ddb2029  2024-09-19T18:27:53Z  2024-09-19T18:27:53Z
# 59         @vale_tantus25  2024-09-12T16:11:26Z  2024-09-12T16:11:26Z
# 64       @PowerPuffJewels  2024-09-07T01:19:44Z  2024-09-07T01:19:44Z
#
#     like_count                                               text  relevant  \
# 18         0.0                                Verstappen the GOAT      True
# 27         0.0             Nando vai chegar na cola do Verstappen      True
# 32         0.0      Max locked in for like only the last few laps      True
# 35         0.0  Jones Elizabeth Rodriguez Charles Williams Jen...      True
# 38         0.0  With 3 laps remaining why did LANDO just jump ...      True
# 45         0.0   Denovo esse mano falando q foguete não dá ré🤦🏾🤣😂      True
# 51         0.0  McLaren Dominating on this one Norris is in a ...      True
# 52         0.0  Lewis and Max absolutely nailed it with the se...      True
# 59         0.0  <a href="https://www.youtube.com/watch?v=yPvoK...      True
# 64         0.0  Can’t wait to see him win races in red along s...      True
#
#                                     driver_sentiments
# 18                     {'Max Verstappen': 'surprise'}
# 27                     {'Max Verstappen': 'surprise'}
# 32                     {'Max Verstappen': 'surprise'}
# 35                    {'Charles Leclerc': 'surprise'}
# 38                            {'Lando Norris': 'joy'}
# 45                                No drivers detected
# 51                            {'Lando Norris': 'joy'}
# 52  {'Lewis Hamilton': 'joy', 'Max Verstappen': 's...
# 59                            {'Lando Norris': 'joy'}
# 64                    {'Charles Leclerc': 'surprise'}

# %%
from collections import defaultdict
emotions_list = ["surprise", "sadness", "joy", "disappointment", "anger"]

import pandas as pd
from collections import defaultdict

# Sample list of drivers and their possible name variations (first and last names)
drivers = {
    "Max Verstappen": ["Max", "Verstappen"],
    "Lewis Hamilton": ["Lewis", "Hamilton"],
    "Lando Norris": ["Lando", "Norris"],
    "Sergio Perez": ["Sergio", "Perez"],
    "Carlos Sainz": ["Carlos", "Sainz"],
    "Oscar Piastri": ["Oscar", "Piastri"]
}

# List of emotions to track
emotions_list = ["surprise", "sadness", "joy", "disappointment", "anger"]

# Initialize the emotion summary dictionary
emotion_summary = {racer: defaultdict(int) for racer in drivers.keys()}

# Iterating through DataFrame rows
for index, row in df_with_emotions.iterrows():
    for racer, name_variations in drivers.items():
        # Checking if any of the driver's name variations (first or last) appears in the comment text (case-insensitive)
        if any(name.lower() in row['text'].lower() for name in name_variations):
            # Extracting emotions from row
            emotions = row['driver_sentiments']

            # Debugging: printing the emotions and row to ensure correct extraction
            print(f"Processing row: {row['text']}")
            print(f"Driver: {racer}, Emotions: {emotions}")

            # If emotions is a valid string and is in the emotions_list, update the emotion count
            if emotions and emotions in emotions_list:
                emotion_summary[racer][emotions] += 1  # Increment the emotion count for the driver

# Convert the summary to a DataFrame for visualization
emotion_df = pd.DataFrame.from_dict(emotion_summary, orient='index', columns=emotions_list)

# Replace missing values (NaN) with 0, as some emotions may not have been encountered
emotion_df = emotion_df.fillna(0)
print(emotion_df)
# Out:
# Streaming output truncated to the last 5000 lines.
# Driver: Carlos Sainz, Emotions: {'Oscar Piastri': 'joy', 'Carlos Sainz': 'anger', 'Sergio Perez': 'surprise'}
# Processing row: Perez is an absolute tool... Blaming Sainz when he had all the space in the world, but he chose to squeeze Sainz against the wall. Absolute tool. Congrats to Oscar!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy', 'Carlos Sainz': 'anger', 'Sergio Perez': 'surprise'}
# Processing row: As a Ferrari Fan Piastri did his thing beautifully. Leclerc doesn&#39;t have that killer instinct.
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'anger', 'Oscar Piastri': 'joy'}
# <br>Now i don&#39;t need your excuses, the shame of you is enough to compensate!!
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# <br>Now i don&#39;t need your excuses, the shame of you is enough to compensate!!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: My favourite race of the season. Battles everywhere. Oscar&#39;s move on Leclerc, Lando defending Checo to prevent the undercut (and then finishing 4th), the crash, the F2 guys scoring points, and of course, the cool down room.
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'joy', 'Charles Leclerc': 'surprise', 'Lando Norris': 'joy'}
# Processing row: My favourite race of the season. Battles everywhere. Oscar&#39;s move on Leclerc, Lando defending Checo to prevent the undercut (and then finishing 4th), the crash, the F2 guys scoring points, and of course, the cool down room.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy', 'Charles Leclerc': 'surprise', 'Lando Norris': 'joy'}
# Processing row: Nobody calling out Perez for that lack of attention, He had so much room to his left but he still kept close to Carlos’s left rear 😑
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'joy', 'Sergio Perez': 'disappointment'}
# Processing row: Nobody calling out Perez for that lack of attention, He had so much room to his left but he still kept close to Carlos’s left rear 😑
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy', 'Sergio Perez': 'disappointment'}
# Processing row: Oscar and Charles both having the best drives of the season in the last 2 races, it&#39;s insane how this season just keeps getting better.
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'surprise', 'Oscar Piastri': 'joy'}
# Processing row: Perez - finally a podium after a long time 🙂🙂<br><br>Sainz: Not yet 🗿🗿
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Perez - finally a podium after a long time 🙂🙂<br><br>Sainz: Not yet 🗿🗿
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Sainz sacrificed himself for the construtor&#39;s lead of his old team ;-;
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'disappointment'}
# Processing row: I don&#39;t know why people say it&#39;s Sainz fault it was definitly perez who caused the crash
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: I don&#39;t know why people say it&#39;s Sainz fault it was definitly perez who caused the crash
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: That looked like team orders to take out the Ferrari. I mean he just turns left and puts them both in the wall to protect Piastri.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Sainz steers left: what happened there?<br>Perez even gives him a little more space when he doesnt even need to
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Sainz steers left: what happened there?<br>Perez even gives him a little more space when he doesnt even need to
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Piastri and Lecrec echoing Hakkinen and Schumacher that was fantastic!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: The accident is more Sainz&#39;s fault but Perez is not %100 right. Sainz shouldn&#39;t have made that move but Perez also could move to the left, he had quite a bit space
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'disappointment', 'Sergio Perez': 'disappointment'}
# Processing row: The accident is more Sainz&#39;s fault but Perez is not %100 right. Sainz shouldn&#39;t have made that move but Perez also could move to the left, he had quite a bit space
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'disappointment', 'Sergio Perez': 'disappointment'}
# Processing row: Charles leclerc started on pole had the race 🏁 under control then Oscar came and took the lead leclerc was trying to overtake him back lewis hamilton started from the pit lane along with the Alpine and forced is way into P9 in the last lap Charles was gaining on the merclaren carlos sainz and perez were fighting for the podium and Sainz closed in and they crashed it was unbelievable on the last lap and George Russell went into 3RD place Oscar piastri wins 🏆 the Azerbaijan 🇦🇿 grand prix Charles leclerc 2nd George russell 3RD and that is the Azerbaijan 🇦🇿 grand prix in 2024 what a race 🏁 and what a finish
# Driver: Lewis Hamilton, Emotions: {'Lewis Hamilton': 'surprise', 'Oscar Piastri': 'surprise', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'surprise', 'Carlos Sainz': 'surprise'}
# Processing row: Charles leclerc started on pole had the race 🏁 under control then Oscar came and took the lead leclerc was trying to overtake him back lewis hamilton started from the pit lane along with the Alpine and forced is way into P9 in the last lap Charles was gaining on the merclaren carlos sainz and perez were fighting for the podium and Sainz closed in and they crashed it was unbelievable on the last lap and George Russell went into 3RD place Oscar piastri wins 🏆 the Azerbaijan 🇦🇿 grand prix Charles leclerc 2nd George russell 3RD and that is the Azerbaijan 🇦🇿 grand prix in 2024 what a race 🏁 and what a finish
# Driver: Sergio Perez, Emotions: {'Lewis Hamilton': 'surprise', 'Oscar Piastri': 'surprise', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'surprise', 'Carlos Sainz': 'surprise'}
# Processing row: Charles leclerc started on pole had the race 🏁 under control then Oscar came and took the lead leclerc was trying to overtake him back lewis hamilton started from the pit lane along with the Alpine and forced is way into P9 in the last lap Charles was gaining on the merclaren carlos sainz and perez were fighting for the podium and Sainz closed in and they crashed it was unbelievable on the last lap and George Russell went into 3RD place Oscar piastri wins 🏆 the Azerbaijan 🇦🇿 grand prix Charles leclerc 2nd George russell 3RD and that is the Azerbaijan 🇦🇿 grand prix in 2024 what a race 🏁 and what a finish
# Driver: Carlos Sainz, Emotions: {'Lewis Hamilton': 'surprise', 'Oscar Piastri': 'surprise', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'surprise', 'Carlos Sainz': 'surprise'}
# Processing row: Charles leclerc started on pole had the race 🏁 under control then Oscar came and took the lead leclerc was trying to overtake him back lewis hamilton started from the pit lane along with the Alpine and forced is way into P9 in the last lap Charles was gaining on the merclaren carlos sainz and perez were fighting for the podium and Sainz closed in and they crashed it was unbelievable on the last lap and George Russell went into 3RD place Oscar piastri wins 🏆 the Azerbaijan 🇦🇿 grand prix Charles leclerc 2nd George russell 3RD and that is the Azerbaijan 🇦🇿 grand prix in 2024 what a race 🏁 and what a finish
# Driver: Oscar Piastri, Emotions: {'Lewis Hamilton': 'surprise', 'Oscar Piastri': 'surprise', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'surprise', 'Carlos Sainz': 'surprise'}
# Processing row: This race was crazy! Gutted for Charles tho! Congrats to Oscar!
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'surprise', 'Oscar Piastri': 'joy'}
# Processing row: <a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=100">1:40</a> are those screens on the edges of Lando&#39;s cockpit alternating between different sponsor names? That seems like it would be super distracting.
# Driver: Lando Norris, Emotions: {'Lando Norris': 'joy'}
# Processing row: FULL BLAME ON CARLOS
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy'}
# Processing row: love to see norris defending against max like max defends against anyone else - not a care in the world about moving under braking and forcing another driver to take avoiding action
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Lando Norris': 'disappointment'}
# Processing row: love to see norris defending against max like max defends against anyone else - not a care in the world about moving under braking and forcing another driver to take avoiding action
# Driver: Lando Norris, Emotions: {'Max Verstappen': 'surprise', 'Lando Norris': 'disappointment'}
# Processing row: Superb drive Oscar.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: What a defense from Oscar Piastri! This guy deserves a world champion.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Sainz 104
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger'}
# Processing row: I hate oscar...he should give lecrec win...coz leclrec now figth wdc with max n lando
# Driver: Max Verstappen, Emotions: {'Oscar Piastri': 'joy', 'Max Verstappen': 'surprise', 'Lando Norris': 'joy'}
# Processing row: I hate oscar...he should give lecrec win...coz leclrec now figth wdc with max n lando
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'joy', 'Max Verstappen': 'surprise', 'Lando Norris': 'joy'}
# Processing row: I hate oscar...he should give lecrec win...coz leclrec now figth wdc with max n lando
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy', 'Max Verstappen': 'surprise', 'Lando Norris': 'joy'}
# Processing row: Piastri is a very chilled driver and what a move from him on Leclerc! Colapinto 8th and Bearman 10th!
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'surprise', 'Oscar Piastri': 'surprise'}
# Processing row: Life time Ban for Sainz, blind af, doesnt know how to defend, cant look his mirrors, he is just too bad to race in F1
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'disappointment'}
# Processing row: Leclerc will still be trying to get past Piastri until next year 😅
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'anger', 'Oscar Piastri': 'surprise'}
# Processing row: At least Oscar actually deserved this one.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Absolutely amazing grand prix amazing piastri
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: perez patetico el comete el error y culpa a sainz
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'anger', 'Sergio Perez': 'disappointment'}
# Processing row: perez patetico el comete el error y culpa a sainz
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger', 'Sergio Perez': 'disappointment'}
# Processing row: 2 race ban for Hamilton for causing the Perez/Sainz collision.
# Driver: Lewis Hamilton, Emotions: {'Lewis Hamilton': 'anger', 'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: 2 race ban for Hamilton for causing the Perez/Sainz collision.
# Driver: Sergio Perez, Emotions: {'Lewis Hamilton': 'anger', 'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: 2 race ban for Hamilton for causing the Perez/Sainz collision.
# Driver: Carlos Sainz, Emotions: {'Lewis Hamilton': 'anger', 'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: Who’s fault is it? Sainz or Perez??
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Who’s fault is it? Sainz or Perez??
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Oscar PS3 yayyy
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: what a driver piastri is!<br><br>edit: <a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=381">6:21</a> the fact that it took 12 seconds for the yellow flag to be shown is a complete joke...
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: <a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=330">5:30</a> Lance Stroll Out from the Race<br><a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=370">6:10</a> Carlos Sainz,Sergio Perez Out from the Race<br><a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=434">7:14</a> Lucas Piastri<br>2 Charles Leclerc <br>3 George Russell
# Driver: Sergio Perez, Emotions: {'Oscar Piastri': 'surprise', 'Carlos Sainz': 'anger', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'anger'}
# Processing row: <a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=330">5:30</a> Lance Stroll Out from the Race<br><a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=370">6:10</a> Carlos Sainz,Sergio Perez Out from the Race<br><a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=434">7:14</a> Lucas Piastri<br>2 Charles Leclerc <br>3 George Russell
# Driver: Carlos Sainz, Emotions: {'Oscar Piastri': 'surprise', 'Carlos Sainz': 'anger', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'anger'}
# Processing row: <a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=330">5:30</a> Lance Stroll Out from the Race<br><a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=370">6:10</a> Carlos Sainz,Sergio Perez Out from the Race<br><a href="https://www.youtube.com/watch?v=7ynDOY1PR74&amp;t=434">7:14</a> Lucas Piastri<br>2 Charles Leclerc <br>3 George Russell
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise', 'Carlos Sainz': 'anger', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'anger'}
# Processing row: McLaren’s number 1… OSCAR !!!!💪👌
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Desde la primera carrera copie que Piastri seria grande 2023... uff que carrera
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Piastri win, Bearman and Colapinto points, Perez and Sainz crash, what a race.
# Driver: Sergio Perez, Emotions: {'Oscar Piastri': 'surprise', 'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Piastri win, Bearman and Colapinto points, Perez and Sainz crash, what a race.
# Driver: Carlos Sainz, Emotions: {'Oscar Piastri': 'surprise', 'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Piastri win, Bearman and Colapinto points, Perez and Sainz crash, what a race.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise', 'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: max dude chin up or u got washed
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: Piastri mega drive <br><br>Norris going from 17th &gt; 15th &gt; 4th and 5 seconds off 3rd in the end <br><br>P1 in WCC for papaya <br><br>Lando even overtook max twice in the same race <br><br>(Once on 30 lap old hards and on the newer mediums)<br><br>And maxs fastest lap attempt on softs got ruined thanks to perez and sainz<br><br><br>Mclaren cooked this race with their strategy
# Driver: Max Verstappen, Emotions: {'Oscar Piastri': 'disappointment', 'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise', 'Carlos Sainz': 'surprise', 'Lando Norris': 'disappointment'}
# Processing row: Piastri mega drive <br><br>Norris going from 17th &gt; 15th &gt; 4th and 5 seconds off 3rd in the end <br><br>P1 in WCC for papaya <br><br>Lando even overtook max twice in the same race <br><br>(Once on 30 lap old hards and on the newer mediums)<br><br>And maxs fastest lap attempt on softs got ruined thanks to perez and sainz<br><br><br>Mclaren cooked this race with their strategy
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'disappointment', 'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise', 'Carlos Sainz': 'surprise', 'Lando Norris': 'disappointment'}
# Processing row: Piastri mega drive <br><br>Norris going from 17th &gt; 15th &gt; 4th and 5 seconds off 3rd in the end <br><br>P1 in WCC for papaya <br><br>Lando even overtook max twice in the same race <br><br>(Once on 30 lap old hards and on the newer mediums)<br><br>And maxs fastest lap attempt on softs got ruined thanks to perez and sainz<br><br><br>Mclaren cooked this race with their strategy
# Driver: Sergio Perez, Emotions: {'Oscar Piastri': 'disappointment', 'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise', 'Carlos Sainz': 'surprise', 'Lando Norris': 'disappointment'}
# Processing row: Piastri mega drive <br><br>Norris going from 17th &gt; 15th &gt; 4th and 5 seconds off 3rd in the end <br><br>P1 in WCC for papaya <br><br>Lando even overtook max twice in the same race <br><br>(Once on 30 lap old hards and on the newer mediums)<br><br>And maxs fastest lap attempt on softs got ruined thanks to perez and sainz<br><br><br>Mclaren cooked this race with their strategy
# Driver: Carlos Sainz, Emotions: {'Oscar Piastri': 'disappointment', 'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise', 'Carlos Sainz': 'surprise', 'Lando Norris': 'disappointment'}
# Processing row: Piastri mega drive <br><br>Norris going from 17th &gt; 15th &gt; 4th and 5 seconds off 3rd in the end <br><br>P1 in WCC for papaya <br><br>Lando even overtook max twice in the same race <br><br>(Once on 30 lap old hards and on the newer mediums)<br><br>And maxs fastest lap attempt on softs got ruined thanks to perez and sainz<br><br><br>Mclaren cooked this race with their strategy
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'disappointment', 'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise', 'Carlos Sainz': 'surprise', 'Lando Norris': 'disappointment'}
# Processing row: FABULOUS!!   What a race for lando and piastri 😍
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: FABULOUS!!   What a race for lando and piastri 😍
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: Well I don&#39;t understand why everyone is either blaming sainz or checo.. At the exit of t2 checo did not leave much space for sainz but he need not to do so because sainz is in the racing line and he would pretty much not move. And in the case of Sainz he was in turning checo to intimate him and go out of the racing line. Neither of them know that their tactics would lead to a crash. We should all accept it&#39;s a racing incident....
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger'}
# Processing row: I saw the entire race and when i saw Perez and Carlos sainz crash i was like 😅
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: I saw the entire race and when i saw Perez and Carlos sainz crash i was like 😅
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: And the Oscar for best defence goes to Piastri!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Kudos to piastri
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Racing incident for Perez and Sainz? <br>Really really unfortunate for them! 😕
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'sadness', 'Sergio Perez': 'sadness'}
# Processing row: Racing incident for Perez and Sainz? <br>Really really unfortunate for them! 😕
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'sadness', 'Sergio Perez': 'sadness'}
# Processing row: piastri show the best drivers in the world how to defend like senna cg to him so much and cg to leclrec and for williams and ollie and hardluck to sainz , verstappen , perez
# Driver: Max Verstappen, Emotions: {'Oscar Piastri': 'surprise', 'Max Verstappen': 'anger', 'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: piastri show the best drivers in the world how to defend like senna cg to him so much and cg to leclrec and for williams and ollie and hardluck to sainz , verstappen , perez
# Driver: Sergio Perez, Emotions: {'Oscar Piastri': 'surprise', 'Max Verstappen': 'anger', 'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: piastri show the best drivers in the world how to defend like senna cg to him so much and cg to leclrec and for williams and ollie and hardluck to sainz , verstappen , perez
# Driver: Carlos Sainz, Emotions: {'Oscar Piastri': 'surprise', 'Max Verstappen': 'anger', 'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: piastri show the best drivers in the world how to defend like senna cg to him so much and cg to leclrec and for williams and ollie and hardluck to sainz , verstappen , perez
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise', 'Max Verstappen': 'anger', 'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: Sainz 😢😢
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy'}
# Processing row: Stop hating on Lando<br>Stop hating on Oscar<br>Both drove an amazing race, let&#39;s just appreciate
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: Stop hating on Lando<br>Stop hating on Oscar<br>Both drove an amazing race, let&#39;s just appreciate
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: Perez was about to finish ahead of max for the first time this season and crashed 😂 😂😂
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Perez was about to finish ahead of max for the first time this season and crashed 😂 😂😂
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Piastri what a masterclass
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Editors are quicker than Oscar!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Carlos is still on that McLaren payroll 😅
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy'}
# Processing row: The run into Abu Dhabi now is going to be epic. Many things can still change with 7 races left to run.<br><br>Piastri was world class up front, so deserves that win.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Norris helps his team mate... but does he team mate help him? Mmm
# Driver: Lando Norris, Emotions: {'Lando Norris': 'surprise'}
# Processing row: Congratulations for Bearman for being the first F1 reserve driver to achieve points in two different teams.<br>Congratulations for Piastri for a well-deserved race win and bringing the team ahead of the WCC.<br>Congratulations for Norris for being capable of finishing ahead of his rival after a miserable Q1 on Saturday.<br>Congratulations for Colapinto for achieving his first points for himself.
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'surprise', 'Lando Norris': 'disappointment'}
# Processing row: Congratulations for Bearman for being the first F1 reserve driver to achieve points in two different teams.<br>Congratulations for Piastri for a well-deserved race win and bringing the team ahead of the WCC.<br>Congratulations for Norris for being capable of finishing ahead of his rival after a miserable Q1 on Saturday.<br>Congratulations for Colapinto for achieving his first points for himself.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise', 'Lando Norris': 'disappointment'}
# Processing row: So many don&#39;t understand here. Sainz is clearly the leading car, he dictates the line. Sainz on corner exit is pinched up against the wall (less than 0.5 car width away) - He naturally moves over and Perez tries to keep him pinned while being half a car length behind and a bus load of space on his left. I don&#39;t think it was intential, probably a racing incident - but more down to Perez.
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'disappointment', 'Sergio Perez': 'anger'}
# Processing row: So many don&#39;t understand here. Sainz is clearly the leading car, he dictates the line. Sainz on corner exit is pinched up against the wall (less than 0.5 car width away) - He naturally moves over and Perez tries to keep him pinned while being half a car length behind and a bus load of space on his left. I don&#39;t think it was intential, probably a racing incident - but more down to Perez.
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'disappointment', 'Sergio Perez': 'anger'}
# Processing row: Bad race considering starting grid of Norris, but it&#39;s a great race for Verstappen without considering it since RBR&#39;s car is so bad now.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'disappointment', 'Lando Norris': 'surprise'}
# Processing row: Bad race considering starting grid of Norris, but it&#39;s a great race for Verstappen without considering it since RBR&#39;s car is so bad now.
# Driver: Lando Norris, Emotions: {'Max Verstappen': 'disappointment', 'Lando Norris': 'surprise'}
# Processing row: best race i&#39;ve seen so far.<br>the wreck was insane. Perez blew Saine&#39;s tire and spun out into the wall what a wreck! I don&#39;t know about Sainz, but Perez should&#39;ve given him space.
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'disappointment'}
# Processing row: best race i&#39;ve seen so far.<br>the wreck was insane. Perez blew Saine&#39;s tire and spun out into the wall what a wreck! I don&#39;t know about Sainz, but Perez should&#39;ve given him space.
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'disappointment'}
# Processing row: Piastri nice one you mad dog
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'anger'}
# Processing row: Piastri being a wailing wall to a monegasque and a mexican… Trump should be proud of him
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'anger'}
# Processing row: Checo has such a great race until him and sainz crashed
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'disappointment'}
# Processing row: Not used to seeing a McLaren at the back.<br>But a deserved win for Piastri
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Piastri highest scoring driver in the last 7 races, even Piastri has a shot on WDC.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: One of the most exciting races of the season by far that ending Williams double points piastri win Bearman points wow!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Verstappen and Perez swapping pace around Baku needs to be studied.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Verstappen and Perez swapping pace around Baku needs to be studied.
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: those final few laps when sainz caught up to perez were pure cinema! (unfortunate outcome) amazing race! <br>also congrats to oscar, he finally has a win not shrouded in controversy
# Driver: Sergio Perez, Emotions: {'Oscar Piastri': 'joy', 'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: those final few laps when sainz caught up to perez were pure cinema! (unfortunate outcome) amazing race! <br>also congrats to oscar, he finally has a win not shrouded in controversy
# Driver: Carlos Sainz, Emotions: {'Oscar Piastri': 'joy', 'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: those final few laps when sainz caught up to perez were pure cinema! (unfortunate outcome) amazing race! <br>also congrats to oscar, he finally has a win not shrouded in controversy
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy', 'Carlos Sainz': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: OSCAR PIASTRI COME BRILLIANTLY HE WON IN BUDAPEST HE WINS IN BAKU OSCAR PIASTRI IS A WINNER OF THE 2024 AZERBAIJAN GRAND PRIX
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Watching Verstappen struggle is therapeutic.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'sadness'}
# Processing row: Honestly 100% Checo’s fault, I have no idea why people blame Sainz, Perez has SO MUCH SPACE on the left side of the car, why does he have to go side by side with Sainz, like, Sainz should not be blamed for that incident, reason he didn’t check his mirrors is because Perez should HAVE NEVER been there…, <b>**</b> weekend as a Ferrari fan
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'disappointment', 'Sergio Perez': 'disappointment'}
# Processing row: Honestly 100% Checo’s fault, I have no idea why people blame Sainz, Perez has SO MUCH SPACE on the left side of the car, why does he have to go side by side with Sainz, like, Sainz should not be blamed for that incident, reason he didn’t check his mirrors is because Perez should HAVE NEVER been there…, <b>**</b> weekend as a Ferrari fan
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'disappointment', 'Sergio Perez': 'disappointment'}
# Processing row: NICE PIASTRI!!!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Leclerc&#39;s pace at the end was mad slow, Sainz really gifted him that podium, once again Russel ending up on the podium because of a crash on basically the final lap 😂
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'surprise', 'Charles Leclerc': 'disappointment'}
# Processing row: Perez is a trash not only he ended his race but Sainz&#39;s race too
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'disappointment'}
# Processing row: Perez is a trash not only he ended his race but Sainz&#39;s race too
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'surprise', 'Sergio Perez': 'disappointment'}
# Processing row: This is proper racing for the win! No late moves under braking, sliding around on the exits, smart ERS usage, a brilliant overtake for the win! What a race, what a drive by Piastri!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Checo: screams his lungs out<br>Carlos: what happened there says calmly<br>smooth operator for life
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy'}
# Processing row: What a race, lando p17 to p4, piastri&#39;s insane drive. Perez and sainz crash, McLaren 1st in constructers championship. One of the best races this year🔥
# Driver: Lando Norris, Emotions: {'Sergio Perez': 'disappointment', 'Carlos Sainz': 'disappointment', 'Oscar Piastri': 'anger', 'Lando Norris': 'joy'}
# Processing row: What a race, lando p17 to p4, piastri&#39;s insane drive. Perez and sainz crash, McLaren 1st in constructers championship. One of the best races this year🔥
# Driver: Sergio Perez, Emotions: {'Sergio Perez': 'disappointment', 'Carlos Sainz': 'disappointment', 'Oscar Piastri': 'anger', 'Lando Norris': 'joy'}
# Processing row: What a race, lando p17 to p4, piastri&#39;s insane drive. Perez and sainz crash, McLaren 1st in constructers championship. One of the best races this year🔥
# Driver: Carlos Sainz, Emotions: {'Sergio Perez': 'disappointment', 'Carlos Sainz': 'disappointment', 'Oscar Piastri': 'anger', 'Lando Norris': 'joy'}
# Processing row: What a race, lando p17 to p4, piastri&#39;s insane drive. Perez and sainz crash, McLaren 1st in constructers championship. One of the best races this year🔥
# Driver: Oscar Piastri, Emotions: {'Sergio Perez': 'disappointment', 'Carlos Sainz': 'disappointment', 'Oscar Piastri': 'anger', 'Lando Norris': 'joy'}
# Processing row: Piastri has the makings of a future champion after overtaking Leclerc.
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'surprise', 'Oscar Piastri': 'surprise'}
# Processing row: Ik Oscar is great but lando from p17 to p4 is incredible!!
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: Ik Oscar is great but lando from p17 to p4 is incredible!!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: Carlos Zans vagabundo Invejoso.......😡😡😡😡
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy'}
# Processing row: What a race! Kudos to Leclerc and Piastri in keeping it clean and respectful. That pass by Oscar was awesome and his lap after lap defending was just fantastic! ☺️👏<br><br>Happy to see McLaren taking the constructors’ lead with a double points finish. 🧡
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'surprise', 'Oscar Piastri': 'joy'}
# Processing row: Piastri can thank Norris for slowing down Perez. Crucial call
# Driver: Lando Norris, Emotions: {'Sergio Perez': 'surprise', 'Oscar Piastri': 'surprise', 'Lando Norris': 'anger'}
# Processing row: Piastri can thank Norris for slowing down Perez. Crucial call
# Driver: Sergio Perez, Emotions: {'Sergio Perez': 'surprise', 'Oscar Piastri': 'surprise', 'Lando Norris': 'anger'}
# Processing row: Piastri can thank Norris for slowing down Perez. Crucial call
# Driver: Oscar Piastri, Emotions: {'Sergio Perez': 'surprise', 'Oscar Piastri': 'surprise', 'Lando Norris': 'anger'}
# Processing row: Insane teamwork by Sainz
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger'}
# Processing row: Lando decided not to lose places on lap 1 for once
# Driver: Lando Norris, Emotions: {'Lando Norris': 'joy'}
# Processing row: poor carlos. Perez&#39;s fault
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'joy', 'Sergio Perez': 'disappointment'}
# Processing row: poor carlos. Perez&#39;s fault
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy', 'Sergio Perez': 'disappointment'}
# Processing row: Why couldn&#39;t Leclerc change tires at the same time as Piastri did?
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'surprise', 'Oscar Piastri': 'surprise'}
# Processing row: Mark Webber is not letting Oscar be the #2 driver
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: I gutted for sainz😢
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy'}
# Processing row: A Piastri Masterclass. He’s so cool under pressure. That’s a major component to becoming a world driving champion.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Piastri has now beaten Norris in 5 of the last 7 races and is not too far behind him in the championship.<br><br>Are McLaren going to regret making Norris number one?
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'surprise', 'Lando Norris': 'surprise'}
# Processing row: Piastri has now beaten Norris in 5 of the last 7 races and is not too far behind him in the championship.<br><br>Are McLaren going to regret making Norris number one?
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise', 'Lando Norris': 'surprise'}
# Processing row: Sainz would had crash whether Perez was there or not
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'disappointment', 'Sergio Perez': 'surprise'}
# Processing row: Sainz would had crash whether Perez was there or not
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'disappointment', 'Sergio Perez': 'surprise'}
# Processing row: 🤩Williams🤩Two drivers is always better than one. Do we really need Sainz 🤔
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy'}
# Processing row: Video/laps are all about Lando 😂😂
# Driver: Lando Norris, Emotions: {'Lando Norris': 'joy'}
# Processing row: Norris gaining 11 positions is just incredible 😲 🔥🔥🔥
# Driver: Lando Norris, Emotions: {'Lando Norris': 'joy'}
# Processing row: Drive of the season worthy race by Piastri today.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Norris played the team game today and will still get hate
# Driver: Lando Norris, Emotions: {'Lando Norris': 'anger'}
# Processing row: &quot;Pressure is for tyres&quot;<br>-Piastri, probably.<br>&quot;What can I say, the podium just turned in on me&quot;<br>-Russel, most likely
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Oscar outclassed Charles today, simple as that.
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'surprise', 'Oscar Piastri': 'joy'}
# Processing row: ⬇️ Sainz’s fault button
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'disappointment'}
# Processing row: Oscar is special.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: This time there are no complaints, only praise, faster than Czech Perez crashing into Carlos🚬
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'joy', 'Sergio Perez': 'anger'}
# Processing row: This time there are no complaints, only praise, faster than Czech Perez crashing into Carlos🚬
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy', 'Sergio Perez': 'anger'}
# Processing row: I&#39;m my opinion, I think Perez caused that crash because Sainz was going straight and Perez was going to the right (straight into Carlos) so I think Perez should get a penalty for next race.
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: I&#39;m my opinion, I think Perez caused that crash because Sainz was going straight and Perez was going to the right (straight into Carlos) so I think Perez should get a penalty for next race.
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger', 'Sergio Perez': 'anger'}
# Processing row: If Lando didn&#39;t hold perez up, an undercut to Oscar would happen. Love him or hate him, Lando is on his way to be on par with Reubens or Valtteri.
# Driver: Lando Norris, Emotions: {'Valtteri Bottas': 'surprise', 'Sergio Perez': 'surprise', 'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: If Lando didn&#39;t hold perez up, an undercut to Oscar would happen. Love him or hate him, Lando is on his way to be on par with Reubens or Valtteri.
# Driver: Sergio Perez, Emotions: {'Valtteri Bottas': 'surprise', 'Sergio Perez': 'surprise', 'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: If Lando didn&#39;t hold perez up, an undercut to Oscar would happen. Love him or hate him, Lando is on his way to be on par with Reubens or Valtteri.
# Driver: Oscar Piastri, Emotions: {'Valtteri Bottas': 'surprise', 'Sergio Perez': 'surprise', 'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: Oscar Piastri masterclass
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Piastri had no fear. A mature drive. Future world champion.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Carlos Sainz needs a race ban. An immediate race ban
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger'}
# Processing row: best race of the year, action every part of it (especially at the end), shock retirements, great defense (and offense) from piastri and two rookies scoring points.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: ⬇️ Sainz’s fault button
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'disappointment'}
# Processing row: Sainz turning left<br>Perez already turning left<br>Look at the white lines
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'anger', 'Sergio Perez': 'surprise'}
# Processing row: Sainz turning left<br>Perez already turning left<br>Look at the white lines
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger', 'Sergio Perez': 'surprise'}
# Processing row: Sainz better not race at the Mexican GP, Hes the public enemy right now
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger'}
# Processing row: At that moment Carlos forget Perez was on my side.
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'joy', 'Sergio Perez': 'surprise'}
# Processing row: At that moment Carlos forget Perez was on my side.
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy', 'Sergio Perez': 'surprise'}
# Processing row: Such a shame to end the 4-way podium fight under VSC after Sainz’s crash into Perez. Did Sainz even look in his mirror?
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'anger', 'Sergio Perez': 'surprise'}
# Processing row: Such a shame to end the 4-way podium fight under VSC after Sainz’s crash into Perez. Did Sainz even look in his mirror?
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger', 'Sergio Perez': 'surprise'}
# Processing row: No puedo creer lo que hizo Carlos Sainz... Por eso está donde está y es el piloto que es
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger'}
# Processing row: Max won&#39;t be the champion this year.<br>Red Bull is finished.<br>Game over man, game over.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: Sainz with zero awareness of his surroundings, off to Williams where he belongs
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'disappointment'}
# Processing row: Thriller of a race! Piastri is the future
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Better be no penalty for the crash, because why was there no penalty for Max, and norris crash!!!!
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Lando Norris': 'anger'}
# Processing row: Better be no penalty for the crash, because why was there no penalty for Max, and norris crash!!!!
# Driver: Lando Norris, Emotions: {'Max Verstappen': 'surprise', 'Lando Norris': 'anger'}
# Processing row: Great race, I was on my toes from start to finish. Congratulations to Oscar and Charles they drove superbly
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'surprise', 'Oscar Piastri': 'joy'}
# Processing row: Piastri is a warrior
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Oscar Piastri won the race in Baku, but Max Verstappen still leads the championship.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Oscar Piastri': 'joy'}
# Processing row: Oscar Piastri won the race in Baku, but Max Verstappen still leads the championship.
# Driver: Oscar Piastri, Emotions: {'Max Verstappen': 'surprise', 'Oscar Piastri': 'joy'}
# Processing row: Carlos S. Tem que ser ponido não é possivel
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'joy'}
# Processing row: Well, what a race. I really enjoyed that one. The battle between Piastri and Leclerc was great. I thought Leclerc would get him back in the end but Piastri drove brilliantly to win the race. Perez and Sainz crashing was a shame as Perez was doing really well this weekend. Lando isn’t really making gains on Max like he should be doing. Looking forward to Singapore.
# Driver: Max Verstappen, Emotions: {'Oscar Piastri': 'surprise', 'Max Verstappen': 'surprise', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'sadness', 'Carlos Sainz': 'sadness', 'Lando Norris': 'joy'}
# Processing row: Well, what a race. I really enjoyed that one. The battle between Piastri and Leclerc was great. I thought Leclerc would get him back in the end but Piastri drove brilliantly to win the race. Perez and Sainz crashing was a shame as Perez was doing really well this weekend. Lando isn’t really making gains on Max like he should be doing. Looking forward to Singapore.
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'surprise', 'Max Verstappen': 'surprise', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'sadness', 'Carlos Sainz': 'sadness', 'Lando Norris': 'joy'}
# Processing row: Well, what a race. I really enjoyed that one. The battle between Piastri and Leclerc was great. I thought Leclerc would get him back in the end but Piastri drove brilliantly to win the race. Perez and Sainz crashing was a shame as Perez was doing really well this weekend. Lando isn’t really making gains on Max like he should be doing. Looking forward to Singapore.
# Driver: Sergio Perez, Emotions: {'Oscar Piastri': 'surprise', 'Max Verstappen': 'surprise', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'sadness', 'Carlos Sainz': 'sadness', 'Lando Norris': 'joy'}
# Processing row: Well, what a race. I really enjoyed that one. The battle between Piastri and Leclerc was great. I thought Leclerc would get him back in the end but Piastri drove brilliantly to win the race. Perez and Sainz crashing was a shame as Perez was doing really well this weekend. Lando isn’t really making gains on Max like he should be doing. Looking forward to Singapore.
# Driver: Carlos Sainz, Emotions: {'Oscar Piastri': 'surprise', 'Max Verstappen': 'surprise', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'sadness', 'Carlos Sainz': 'sadness', 'Lando Norris': 'joy'}
# Processing row: Well, what a race. I really enjoyed that one. The battle between Piastri and Leclerc was great. I thought Leclerc would get him back in the end but Piastri drove brilliantly to win the race. Perez and Sainz crashing was a shame as Perez was doing really well this weekend. Lando isn’t really making gains on Max like he should be doing. Looking forward to Singapore.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise', 'Max Verstappen': 'surprise', 'Charles Leclerc': 'surprise', 'Sergio Perez': 'sadness', 'Carlos Sainz': 'sadness', 'Lando Norris': 'joy'}
# Processing row: I didn&#39;t think Lando would overtake Max on track, WOW!!🔥Just needs to get his mentality straight he has the pace.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Lando Norris': 'joy'}
# Processing row: I didn&#39;t think Lando would overtake Max on track, WOW!!🔥Just needs to get his mentality straight he has the pace.
# Driver: Lando Norris, Emotions: {'Max Verstappen': 'surprise', 'Lando Norris': 'joy'}
# Processing row: Commentator: <br>&quot;WOW!! Perez might finish ahead of Verstappen for a change.&quot;<br><br>Perez: <br>&quot;Just when they think they have got the answers, I change the questions.&quot;
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Commentator: <br>&quot;WOW!! Perez might finish ahead of Verstappen for a change.&quot;<br><br>Perez: <br>&quot;Just when they think they have got the answers, I change the questions.&quot;
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Charles never got finish P1 after Piastri edging him for whole 25+ laps
# Driver: Oscar Piastri, Emotions: {'Charles Leclerc': 'surprise', 'Oscar Piastri': 'anger'}
# Processing row: 100% Sainz fault!!!!<br><br>Piastri &gt; Norris
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'surprise', 'Carlos Sainz': 'anger', 'Lando Norris': 'anger'}
# Processing row: 100% Sainz fault!!!!<br><br>Piastri &gt; Norris
# Driver: Carlos Sainz, Emotions: {'Oscar Piastri': 'surprise', 'Carlos Sainz': 'anger', 'Lando Norris': 'anger'}
# Processing row: 100% Sainz fault!!!!<br><br>Piastri &gt; Norris
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise', 'Carlos Sainz': 'anger', 'Lando Norris': 'anger'}
# Processing row: What a race ! GO OSCAR 🇦🇺🇦🇺🇦🇺
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: 10 second penalty for Ocon for the Sainz and Perez collision
# Driver: Sergio Perez, Emotions: {'Carlos Sainz': 'anger', 'Esteban Ocon': 'anger', 'Sergio Perez': 'anger'}
# Processing row: 10 second penalty for Ocon for the Sainz and Perez collision
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'anger', 'Esteban Ocon': 'anger', 'Sergio Perez': 'anger'}
# Processing row: Piastri drove beautifully<br><br>That crash was clearly Perez&#39;s fault, Sainz ahead has priority on the racing line and Perez didn&#39;t move at all.
# Driver: Sergio Perez, Emotions: {'Oscar Piastri': 'disappointment', 'Carlos Sainz': 'disappointment', 'Sergio Perez': 'disappointment'}
# Processing row: Piastri drove beautifully<br><br>That crash was clearly Perez&#39;s fault, Sainz ahead has priority on the racing line and Perez didn&#39;t move at all.
# Driver: Carlos Sainz, Emotions: {'Oscar Piastri': 'disappointment', 'Carlos Sainz': 'disappointment', 'Sergio Perez': 'disappointment'}
# Processing row: Piastri drove beautifully<br><br>That crash was clearly Perez&#39;s fault, Sainz ahead has priority on the racing line and Perez didn&#39;t move at all.
# ...
# Processing row: Max starting 9 places behind perez and still be ahead him in the end is crazy
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'anger'}
# Processing row: Max starting 9 places behind perez and still be ahead him in the end is crazy
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'anger'}
# Processing row: Piastri is a revelation. He overtakes like a champion.
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Norris can never be a world champion if he keeps on botching race starts
# Driver: Lando Norris, Emotions: {'Lando Norris': 'disappointment'}
# Processing row: Verstappen beating perez and Norris is a very humiliating thing to think about... Awesome drive from max
# Driver: Max Verstappen, Emotions: {'Sergio Perez': 'disappointment', 'Max Verstappen': 'disappointment', 'Lando Norris': 'disappointment'}
# Processing row: Verstappen beating perez and Norris is a very humiliating thing to think about... Awesome drive from max
# Driver: Lando Norris, Emotions: {'Sergio Perez': 'disappointment', 'Max Verstappen': 'disappointment', 'Lando Norris': 'disappointment'}
# Processing row: Verstappen beating perez and Norris is a very humiliating thing to think about... Awesome drive from max
# Driver: Sergio Perez, Emotions: {'Sergio Perez': 'disappointment', 'Max Verstappen': 'disappointment', 'Lando Norris': 'disappointment'}
# Processing row: If this is checos last race with red bull let us be reminded that he is maxs most competent teammate since daniel.
# Driver: Max Verstappen, Emotions: {'Daniel Ricciardo': 'sadness'}
# Processing row: WHAT A DRIVE PIASTRI!!!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Any race is a decent race when Max doesn&#39;t win
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: Great drive by Russell and by Piastri!!
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: Piastri had a mighty drive
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Sainz was going for the same one stop strategy and then Ferrari  changed to a Ferrari strategy
# Driver: Carlos Sainz, Emotions: {'Carlos Sainz': 'surprise'}
# Processing row: So if it isn’t for Max pushing the RB20 to its absolute limit, RedBull are now a midfield team.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: I still think Max will win the championship😂😂😂
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: Russell&#39;s drive was brilliant, but the strategy by Mercedes was risky. Letting Hamilton pass would have been a better way to keep Piastri at bay. They allowed him to get within a second at the end. Could have lost the top spots
# Driver: Lewis Hamilton, Emotions: {'Lewis Hamilton': 'disappointment', 'Oscar Piastri': 'surprise'}
# Processing row: Russell&#39;s drive was brilliant, but the strategy by Mercedes was risky. Letting Hamilton pass would have been a better way to keep Piastri at bay. They allowed him to get within a second at the end. Could have lost the top spots
# Driver: Oscar Piastri, Emotions: {'Lewis Hamilton': 'disappointment', 'Oscar Piastri': 'surprise'}
# Processing row: Norris started ahead of Verstappen and he still lost 2 points to him 😂
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'disappointment', 'Lando Norris': 'disappointment'}
# Processing row: Norris started ahead of Verstappen and he still lost 2 points to him 😂
# Driver: Lando Norris, Emotions: {'Max Verstappen': 'disappointment', 'Lando Norris': 'disappointment'}
# Processing row: No way Checo has the same car as verstappen 😂
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'joy'}
# Processing row: max didn’t win so i don’t have to eat my foot😁
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: OSCAR PODIUM LETSGOO
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: and Max yet doesnt get a win, RedBull is really struggling arn&#39;t they ?
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: Os an Piastri fan, I wanna congratulations George! He deserves that!! <br>Mercedes is backkk
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: could lando norris win 2024 championship
# Driver: Lando Norris, Emotions: {'Lando Norris': 'joy'}
# Processing row: Feels bad for Perez. Started #2 but still finished the race behind Verstappen who started #10.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Feels bad for Perez. Started #2 but still finished the race behind Verstappen who started #10.
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: How does Lando and McLaren continue failing to reduce Max’s points advantage even when they had a rocket ship today is beyond me
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Lando Norris': 'joy'}
# Processing row: How does Lando and McLaren continue failing to reduce Max’s points advantage even when they had a rocket ship today is beyond me
# Driver: Lando Norris, Emotions: {'Max Verstappen': 'surprise', 'Lando Norris': 'joy'}
# Processing row: People still think Norris is on the level of Russell?? 😂😂
# Driver: Lando Norris, Emotions: {'Lando Norris': 'surprise'}
# Processing row: If Verstappen had started on the front row he still would not have won. Chew over that.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'disappointment'}
# Processing row: That ending race from Piastri, Hamilton and Russel was super exciting! Man what an amazing race, it was mega enjoyable!
# Driver: Lewis Hamilton, Emotions: {'Lewis Hamilton': 'joy', 'Oscar Piastri': 'joy'}
# Processing row: That ending race from Piastri, Hamilton and Russel was super exciting! Man what an amazing race, it was mega enjoyable!
# Driver: Oscar Piastri, Emotions: {'Lewis Hamilton': 'joy', 'Oscar Piastri': 'joy'}
# Processing row: If Max started at pole, it would have been another boring race. <br><br>He should lend Perez his chiropractor ASAP.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: If Max started at pole, it would have been another boring race. <br><br>He should lend Perez his chiropractor ASAP.
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Not having Verstappen on the podium, I&#39;m happy.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'joy'}
# Processing row: George and Mercedes can thank McLaren for the win. Oscar was 5-6 seconds ahead of Russell and 0.6 seconds faster than him per lap. He pitted way later than Hamilton and Verstappen. So, the strategists who pitted those drivers I am fine with. But Oscar pitted so late. Like you left him out for so long and didn&#39;t commit. When will they stop sacrificing this man?
# Driver: Max Verstappen, Emotions: {'Lewis Hamilton': 'surprise', 'Max Verstappen': 'surprise', 'Oscar Piastri': 'joy'}
# Processing row: George and Mercedes can thank McLaren for the win. Oscar was 5-6 seconds ahead of Russell and 0.6 seconds faster than him per lap. He pitted way later than Hamilton and Verstappen. So, the strategists who pitted those drivers I am fine with. But Oscar pitted so late. Like you left him out for so long and didn&#39;t commit. When will they stop sacrificing this man?
# Driver: Lewis Hamilton, Emotions: {'Lewis Hamilton': 'surprise', 'Max Verstappen': 'surprise', 'Oscar Piastri': 'joy'}
# Processing row: George and Mercedes can thank McLaren for the win. Oscar was 5-6 seconds ahead of Russell and 0.6 seconds faster than him per lap. He pitted way later than Hamilton and Verstappen. So, the strategists who pitted those drivers I am fine with. But Oscar pitted so late. Like you left him out for so long and didn&#39;t commit. When will they stop sacrificing this man?
# Driver: Oscar Piastri, Emotions: {'Lewis Hamilton': 'surprise', 'Max Verstappen': 'surprise', 'Oscar Piastri': 'joy'}
# Processing row: What a way to finish with less than 2 seconds in the top 3 and the same for the battle for 4th place!  Well done George and Lewis. And Oscar was a beast in the final part of the race
# Driver: Lewis Hamilton, Emotions: {'Lewis Hamilton': 'joy', 'Oscar Piastri': 'joy'}
# Processing row: What a way to finish with less than 2 seconds in the top 3 and the same for the battle for 4th place!  Well done George and Lewis. And Oscar was a beast in the final part of the race
# Driver: Oscar Piastri, Emotions: {'Lewis Hamilton': 'joy', 'Oscar Piastri': 'joy'}
# Processing row: Seems like qualifying doesn’t make any difference for Perez he always finishes last behind Max and the McLaren, Ferrari and Mercedes
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'disappointment'}
# Processing row: Seems like qualifying doesn’t make any difference for Perez he always finishes last behind Max and the McLaren, Ferrari and Mercedes
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'disappointment'}
# Processing row: Norris having bad start as usual 😢
# Driver: Lando Norris, Emotions: {'Lando Norris': 'disappointment'}
# Processing row: By the duch gp Verstappen will have not won for 2 months!
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'disappointment'}
# Processing row: Give Lando the fastest car and he still decides to turn into a midfield driver..i guess he is hanging out with Checo too often..what a disaster
# Driver: Lando Norris, Emotions: {'Lando Norris': 'joy'}
# Processing row: Lando gotta stop bottling his starts
# Driver: Lando Norris, Emotions: {'Lando Norris': 'joy'}
# Processing row: max had a chance😢😢
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: Russell clears Norris after today
# Driver: Lando Norris, Emotions: {'Lando Norris': 'disappointment'}
# Processing row: Max still finished in front of Perez. Welcome back Ricciardo!
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Daniel Ricciardo': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: Max still finished in front of Perez. Welcome back Ricciardo!
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'surprise', 'Daniel Ricciardo': 'surprise', 'Sergio Perez': 'surprise'}
# Processing row: looks like Max is nothing without a 1 second a lap faster car...LOL
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: reality called Norris
# Driver: Lando Norris, Emotions: {'Lando Norris': 'anger'}
# Processing row: F1 is so back without verstappen on the podium
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: Verstappen doing the best he could, while Perez doing Perez things
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'anger', 'Sergio Perez': 'surprise'}
# Processing row: Verstappen doing the best he could, while Perez doing Perez things
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'anger', 'Sergio Perez': 'surprise'}
# Processing row: Lewis loosing to his teammate on much fresher tyres and on a track where overtaking difficulty is 1/10 goes on to show why Max is a very tall order.<br>btw Impressive drive from Russell, didn&#39;t think he&#39;d be able to hold it for that long
# Driver: Max Verstappen, Emotions: {'Lewis Hamilton': 'joy', 'Max Verstappen': 'surprise'}
# Processing row: Lewis loosing to his teammate on much fresher tyres and on a track where overtaking difficulty is 1/10 goes on to show why Max is a very tall order.<br>btw Impressive drive from Russell, didn&#39;t think he&#39;d be able to hold it for that long
# Driver: Lewis Hamilton, Emotions: {'Lewis Hamilton': 'joy', 'Max Verstappen': 'surprise'}
# Processing row: how tf Norris managed to finish behind Max even tho he started in front?
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Lando Norris': 'surprise'}
# Processing row: how tf Norris managed to finish behind Max even tho he started in front?
# Driver: Lando Norris, Emotions: {'Max Verstappen': 'surprise', 'Lando Norris': 'surprise'}
# Processing row: Lando on 1 tyre strat could’ve been incredible
# Driver: Lando Norris, Emotions: {'Lando Norris': 'joy'}
# Processing row: Lando has to be the worst starter since Piastri&#39;s manager, Mark Webber.....
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: Lando has to be the worst starter since Piastri&#39;s manager, Mark Webber.....
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy', 'Lando Norris': 'joy'}
# Processing row: Piastri is clearly going to be a champion in the near future if McLaren keeps making fast cars
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise'}
# Processing row: Russel disqualified so Hamilton wins.<br>Piastri almost took his jackman with him to the podium.. that cost him the win
# Driver: Lewis Hamilton, Emotions: {'Lewis Hamilton': 'surprise', 'Oscar Piastri': 'surprise'}
# Processing row: Russel disqualified so Hamilton wins.<br>Piastri almost took his jackman with him to the podium.. that cost him the win
# Driver: Oscar Piastri, Emotions: {'Lewis Hamilton': 'surprise', 'Oscar Piastri': 'surprise'}
# Processing row: Checko started 2nd, Max started 11th. <br>Checko finished 7th, Max finished 5th. <br><br>I think Max has broken Checko once again, just like in Miami last year.
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: ¿Donde estas Verstappen? ¿Verstappen donde estas? 🎵🎵🎵🎵
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: Perez getting cooked by verstappen is insane
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'anger', 'Sergio Perez': 'anger'}
# Processing row: Perez getting cooked by verstappen is insane
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'anger', 'Sergio Perez': 'anger'}
# Processing row: Verstappen is still winning the championship but the constructors isn’t going to Red Bull as long as Sergio Perez is Sergio Perez
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'anger'}
# Processing row: Verstappen is still winning the championship but the constructors isn’t going to Red Bull as long as Sergio Perez is Sergio Perez
# Driver: Sergio Perez, Emotions: {'Max Verstappen': 'surprise', 'Sergio Perez': 'anger'}
# Processing row: Max doing Max things and still gaining against his championship rival while the Red Bull car is worse
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: Lando’s doing more damage for the championship position
# Driver: Lando Norris, Emotions: {'Lando Norris': 'joy'}
# Processing row: Man I was really rooting for Oscar at the end 😅
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'joy'}
# Processing row: George&gt;&gt;Piastri&gt;&gt;Lando
# Driver: Lando Norris, Emotions: {'Oscar Piastri': 'surprise', 'Lando Norris': 'joy'}
# Processing row: George&gt;&gt;Piastri&gt;&gt;Lando
# Driver: Oscar Piastri, Emotions: {'Oscar Piastri': 'surprise', 'Lando Norris': 'joy'}
# Processing row: Du du du max Verstappen
# Driver: Max Verstappen, Emotions: {'Max Verstappen': 'surprise'}
# Processing row: I swear Lewis Hamilton losing to George today is even more painful than when he was robbed in Abu Dhabi. I honestly understand why he&#39;s not happy. I would rather have Lewis lose to Max Verstappen than lose to George!
# Driver: Max Verstappen, Emotions: {'Lewis Hamilton': 'sadness', 'Max Verstappen': 'anger'}
# Processing row: I swear Lewis Hamilton losing to George today is even more painful than when he was robbed in Abu Dhabi. I honestly understand why he&#39;s not happy. I would rather have Lewis lose to Max Verstappen than lose to George!
# Driver: Lewis Hamilton, Emotions: {'Lewis Hamilton': 'sadness', 'Max Verstappen': 'anger'}
# Empty DataFrame
# Columns: [surprise, sadness, joy, disappointment, anger]
# Index: []

# %%
import pandas as pd

# list of racer names
racers = ['Verstappen', 'Norris', 'Leclerc', 'Piastri', 'Sainz' ]

# Identifying racers mentioned in each comment, handling NaN values
def identify_racer(text):
    if isinstance(text, str):  # Only process if text is a string
        mentioned_racers = [racer for racer in racers if racer.lower() in text.lower()]
        return mentioned_racers[0] if mentioned_racers else None
    return None

# Applying the function to the 'text' column and create a new 'racer' column
df['racer'] = df['text'].apply(identify_racer)

# Filtering out comments without racer mentions
df = df.dropna(subset=['racer'])

# %% [markdown]
# # Section 5: Sentiment Analysis with VADER

# %% [markdown]
# This section utilizes the VADER sentiment analyzer to determine the overall sentiment of each comment

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

nltk.download('vader_lexicon')

# Initialize VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Define a function to map sentiment scores to emotions
def get_emotion(text):
    score = sia.polarity_scores(text)

    if score['compound'] >= 0.6:
        return 'joy'
    elif score['compound'] >= 0.2:
        return 'surprise'
    elif score['compound'] > -0.2:
        return 'neutral'
    elif score['compound'] > -0.6:
        return 'sad'
    else:
        return 'anger'


df['emotion'] = df['text'].apply(get_emotion)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# <ipython-input-20-ace61842d46e>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emotion'] = df['text'].apply(get_emotion)

# %% [markdown]
# # Section 6: Visualization and Reporting

# %% [markdown]
# This section creates visualizations and reports to present the results of the analysis, such as trends in sentiment and emotion over time.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='racer', hue='emotion')
plt.title("Emotion Distribution for Each Racer")
plt.xlabel("Racer")
plt.ylabel("Count of Comments")
plt.legend(title="Emotion")
plt.show()

# %%
plt.figure(figsize=(10, 6))
emotion_counts = df.groupby(['racer', 'emotion']).size().unstack(fill_value=0)
emotion_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title("Top Emotions for Each Racer")
plt.xlabel("Racer")
plt.ylabel("Number of Comments")
plt.show()

# %%
df['published_at'] = pd.to_datetime(df['published_at'])

sentiment_over_time = df.groupby(['published_at', 'racer', 'emotion']).size().unstack(fill_value=0).reset_index()


plt.figure(figsize=(14, 8))
for racer in racers:
    racer_data = sentiment_over_time[sentiment_over_time['racer'] == racer]
    plt.plot(racer_data['published_at'], racer_data['joy'], label=f"{racer} - Joy", linestyle='-', marker='o')
    plt.plot(racer_data['published_at'], racer_data['sad'], label=f"{racer} - Sad", linestyle='--', marker='x')


plt.xlabel('Date')
plt.ylabel('Emotion Count')
plt.title("Sentiment Trend for Each Racer Over Time")
plt.legend(title="Emotion by Racer", loc='best')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-23-71969630474d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['published_at'] = pd.to_datetime(df['published_at'])

# %%
top_positive_racers = df[df['emotion'] == 'joy']['racer'].value_counts().nlargest(5)

plt.figure(figsize=(8, 6))
sns.barplot(x=top_positive_racers.index, y=top_positive_racers.values, palette="viridis")
plt.title("Top Racers by Positive Sentiment")
plt.xlabel("Racer")
plt.ylabel("Number of Positive Comments")
plt.show()
# Out:
# <ipython-input-24-d119988dcebb>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_positive_racers.index, y=top_positive_racers.values, palette="viridis")

# %%
top_negative_racers = df[df['emotion'] == 'anger']['racer'].value_counts().nlargest(5)

plt.figure(figsize=(8, 6))
sns.barplot(x=top_negative_racers.index, y=top_negative_racers.values, palette="inferno")
plt.title("Top Racers by Negative Sentiment")
plt.xlabel("Racer")
plt.ylabel("Number of Negative Comments")
plt.show()
# Out:
# <ipython-input-25-bbd391c42367>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_negative_racers.index, y=top_negative_racers.values, palette="inferno")

# %%
emotion_mapping = {
    'joy': 1,  # Assign a positive score for joy
    'surprise': 0.5,  # Assign a neutral score for surprise
    'neutral': 0,  # Assign a neutral score for neutral
    'sad': -0.5,  # Assign a negative score for sad
    'anger': -1  # Assign a negative score for anger
}
df['sentiment_score'] = df['emotion'].map(emotion_mapping)  # Create a sentiment score column

# Add a 'constructor' column to constructor mapping
racer_to_constructor = {
    'Verstappen': 'Red Bull',
    'Norris': 'McLaren',
    'Leclerc': 'Ferrari',
    'Piastri': 'McLaren',
    'Sainz': 'Ferrari'
}
# Apply the mapping to create the 'constructor' column
df['constructor'] = df['racer'].map(racer_to_constructor)

# Create the boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='constructor', y='sentiment_score')
plt.title('Sentiment Distribution by Constructor', fontsize=16)
plt.xlabel('Constructor', fontsize=14)
plt.ylabel('Sentiment Score', fontsize=14)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-26-16f4bc4957b8>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment_score'] = df['emotion'].map(emotion_mapping)  # Create a sentiment score column
# <ipython-input-26-16f4bc4957b8>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['constructor'] = df['racer'].map(racer_to_constructor)

# %%
heatmap_data = df.groupby(['racer', 'constructor'])['sentiment_score'].mean().unstack()

# Plotting the heatmap
plt.figure(figsize=(14, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap='coolwarm', cbar_kws={'label': 'Sentiment Score'})
plt.title('Racer vs Constructor Sentiment Comparison', fontsize=16)
plt.xlabel('Constructor', fontsize=14)
plt.ylabel('Racer', fontsize=14)
# Out:
# Text(145.72222222222223, 0.5, 'Racer')

# %%
import pandas as pd
import zipfile
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

nltk.download('vader_lexicon')

# Path to the zip file
zip_file_path = '/content/Data.zip'

# Create a ZipFile object
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Get a list of all CSV files within the archive
    csv_files = [file for file in zip_ref.namelist() if file.endswith('.csv')]

    dataframes = []
    # Iterate through each CSV file
    for csv_file in csv_files:
        # Read the CSV file directly from the zip archive
        with zip_ref.open(csv_file, 'r') as file:
            df = pd.read_csv(file)
            # Add a new column 'csv_filename' to store the filename
            df['csv_filename'] = csv_file  # Store the filename
            dataframes.append(df)

# Concatenate all dataframes
df = pd.concat(dataframes, ignore_index=True)
print(df)

#Racer names
racers = ['Verstappen', 'Norris', 'Leclerc', 'Piastri', 'Sainz' ]
def identify_racer(text):
    if isinstance(text, str):  # Only process if text is a string
        mentioned_racers = [racer for racer in racers if racer.lower() in text.lower()]
        return mentioned_racers[0] if mentioned_racers else None
    return None
df['racer'] = df['text'].apply(identify_racer)
df = df.dropna(subset=['racer'])

sia = SentimentIntensityAnalyzer()
def get_emotion(text):
    score = sia.polarity_scores(text)

    if score['compound'] >= 0.6:
        return 'joy'
    elif score['compound'] >= 0.2:
        return 'surprise'
    elif score['compound'] > -0.2:
        return 'neutral'
    elif score['compound'] > -0.6:
        return 'sad'
    else:
        return 'anger'
df['emotion'] = df['text'].apply(get_emotion)

emotion_mapping = {
    'joy': 1,  # Assign a positive score for joy
    'surprise': 0.5,  # Assign a neutral score for surprise
    'neutral': 0,  # Assign a neutral score for neutral
    'sad': -0.5,  # Assign a negative score for sad
    'anger': -1  # Assign a negative score for anger
}
df['sentiment_score'] = df['emotion'].map(emotion_mapping)
# ...

def get_country_from_filename(filename):
    country = filename.split("_")[0]
    return country

df['country'] = df['csv_filename'].apply(get_country_from_filename)
# Add a new column to store sentiment for each individual comment
df['comment_sentiment'] = df['text'].apply(get_emotion)

# Group by country and racer, calculate sentiment distribution for each group
country_racer_sentiment = df.groupby(['country', 'racer', 'comment_sentiment'])['text'].count().reset_index(name='comment_count')

# Now group by 'country' and 'emotion':
country_sentiment = df.groupby(['country', 'emotion'])['sentiment_score'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(data=country_sentiment, x='country', y='sentiment_score', hue='emotion')
plt.title('Average Sentiment Score by Country and Emotion')
plt.xlabel('Country')
plt.ylabel('Average Sentiment Score')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                             author          published_at  \
# 0            @michaelcortright5525  2024-12-08T16:02:35Z
# 1                         @oreskec  2024-12-08T11:50:44Z
# 2                       @Bilnation  2024-12-07T22:39:57Z
# 3                   @anthonymg8870  2024-12-07T10:23:59Z
# 4      @mykatiesdouglaskatie-kp1jg  2024-12-06T05:34:57Z
# ...                            ...                   ...
# 61922                  @AhmadRiyal  2024-07-28T15:49:24Z
# 61923              @DayTimeRunners  2024-07-28T15:49:21Z
# 61924                     @Topsu11  2024-07-28T15:49:20Z
# 61925          @eliashargaming6143  2024-07-28T15:49:19Z
# 61926                 @sameern9018  2024-07-28T15:49:15Z
#
#                  updated_at  like_count  \
# 0      2024-12-08T16:02:35Z         0.0
# 1      2024-12-08T11:50:44Z         0.0
# 2      2024-12-07T22:39:57Z         2.0
# 3      2024-12-07T10:23:59Z         0.0
# 4      2024-12-06T05:34:57Z         0.0
# ...                     ...         ...
# 61922  2024-07-28T15:49:24Z         0.0
# 61923  2024-07-28T15:49:21Z         0.0
# 61924  2024-07-28T15:49:20Z         1.0
# 61925  2024-07-28T16:56:34Z      2434.0
# 61926  2024-07-28T15:49:15Z        13.0
#
#                                                     text csv_filename
# 0      I cried when it happened and I cried again wat...  British.csv
# 1      <a href="https://www.youtube.com/watch?v=yPvoK...  British.csv
# 2      This was the best Silverstone race of all time...  British.csv
# 3      I remember watching this race. It was mouthwat...  British.csv
# 4                                           Missing this  British.csv
# ...                                                  ...          ...
# 61922                                              First  Belgian.csv
# 61923                                            Amazing  Belgian.csv
# 61924                                              First  Belgian.csv
# 61925  That was the drive of the year from George Rus...  Belgian.csv
# 61926                                       First view 🥇  Belgian.csv
#
# [61927 rows x 6 columns]
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
heatmap_data = country_sentiment.pivot(index='country', columns='emotion', values='sentiment_score')
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap='coolwarm', cbar_kws={'label': 'Average Sentiment Score'})
plt.title('Sentiment Score by Country and Emotion')
plt.show()

# %%
from wordcloud import WordCloud

# Generating positive sentiment word cloud
positive_text = " ".join(df[df['sentiment_score'] > 0]['text'])
positive_wc = WordCloud(width=800, height=400, background_color='white').generate(positive_text)

plt.figure(figsize=(10, 6))
plt.imshow(positive_wc, interpolation='bilinear')
plt.title('Word Cloud for Positive Sentiment', fontsize=16)
plt.axis('off')
plt.show()

# %%
# Generating negative sentiment word cloud
negative_text = " ".join(df[df['sentiment_score'] < 0]['text'])
negative_wc = WordCloud(width=800, height=400, background_color='black').generate(negative_text)

plt.figure(figsize=(10, 6))
plt.imshow(negative_wc, interpolation='bilinear')
plt.title('Word Cloud for Negative Sentiment', fontsize=16)
plt.axis('off')
plt.show()

# %% [markdown]
# # Section 7: Time-based analysis

# %% [markdown]
#  This section focuses on time-based trends in comment volume and sentiment for specific racers and teams.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'published_at' to datetime
df['published_at'] = pd.to_datetime(df['published_at'])

# Group by date and racer, counting comments
comment_count_over_time = df.groupby(['published_at', 'racer'])['text'].count().reset_index(name='comment_count')

# Select the racer you want to visualize (e.g., 'Verstappen')
selected_racer = 'Verstappen'

# Filter data for the selected racer
racer_data = comment_count_over_time[comment_count_over_time['racer'] == selected_racer]

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(racer_data['published_at'], racer_data['comment_count'], marker='o', linestyle='-')
plt.title(f'Comment Count for {selected_racer} Over Time')
plt.xlabel('Date')
plt.ylabel('Comment Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting for multiple racers
plt.figure(figsize=(12, 5))
for racer in racers:
    racer_data = comment_count_over_time[comment_count_over_time['racer'] == racer]
    plt.plot(racer_data['published_at'], racer_data['comment_count'], marker='o', linestyle='-', label=racer)

plt.title('Comment Count for Racers Over Time')
plt.xlabel('Date')
plt.ylabel('Comment Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by racer and emotion, count occurrences
sentiment_counts = df.groupby(['racer', 'emotion']).size().reset_index(name='counts')

# Pivot the table to have racers as index and emotions as columns
sentiment_pivot = sentiment_counts.pivot(index='racer', columns='emotion', values='counts')

# Fill NaN values with 0
sentiment_pivot = sentiment_pivot.fillna(0)

# Select a specific racer (e.g., Verstappen)
racer_name = 'Verstappen'
sentiment_data = sentiment_pivot.loc[racer_name]

# Get emotion labels and counts for the selected racer
labels = sentiment_data.index
sizes = sentiment_data.values

# %%
# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title(f'Sentiment Distribution for {racer_name}')
plt.show()
